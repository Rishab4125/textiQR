# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishab4125/qr_scanner/blob/main/testing_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings

def fxn():
    warnings.warn("deprecated", DeprecationWarning)

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %%
# !pip install qreader
# !sudo apt-get install libzbar0
# Out:
# Collecting qreader
#   Downloading qreader-3.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from qreader) (1.26.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from qreader) (4.10.0.84)
# Collecting pyzbar (from qreader)
#   Downloading pyzbar-0.1.9-py2.py3-none-any.whl.metadata (10 kB)
# Collecting qrdet>=2.5 (from qreader)
#   Downloading qrdet-2.5-py3-none-any.whl.metadata (6.7 kB)
# Collecting ultralytics (from qrdet>=2.5->qreader)
#   Downloading ultralytics-8.3.59-py3-none-any.whl.metadata (35 kB)
# Collecting quadrilateral-fitter (from qrdet>=2.5->qreader)
#   Downloading quadrilateral_fitter-1.12-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from qrdet>=2.5->qreader) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from qrdet>=2.5->qreader) (4.67.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from quadrilateral-fitter->qrdet>=2.5->qreader) (2.0.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from quadrilateral-fitter->qrdet>=2.5->qreader) (1.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->qrdet>=2.5->qreader) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->qrdet>=2.5->qreader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->qrdet>=2.5->qreader) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->qrdet>=2.5->qreader) (2024.12.14)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics->qrdet>=2.5->qreader) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics->qrdet>=2.5->qreader) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics->qrdet>=2.5->qreader) (6.0.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics->qrdet>=2.5->qreader) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics->qrdet>=2.5->qreader) (0.20.1+cu121)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics->qrdet>=2.5->qreader) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics->qrdet>=2.5->qreader) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics->qrdet>=2.5->qreader) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics->qrdet>=2.5->qreader) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics->qrdet>=2.5->qreader)
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics->qrdet>=2.5->qreader) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics->qrdet>=2.5->qreader) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics->qrdet>=2.5->qreader) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics->qrdet>=2.5->qreader) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics->qrdet>=2.5->qreader) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics->qrdet>=2.5->qreader) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics->qrdet>=2.5->qreader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics->qrdet>=2.5->qreader) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics->qrdet>=2.5->qreader) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics->qrdet>=2.5->qreader) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics->qrdet>=2.5->qreader) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics->qrdet>=2.5->qreader) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics->qrdet>=2.5->qreader) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics->qrdet>=2.5->qreader) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics->qrdet>=2.5->qreader) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics->qrdet>=2.5->qreader) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics->qrdet>=2.5->qreader) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics->qrdet>=2.5->qreader) (3.0.2)
# Downloading qreader-3.14-py3-none-any.whl (17 kB)
# Downloading qrdet-2.5-py3-none-any.whl (22 kB)
# Downloading pyzbar-0.1.9-py2.py3-none-any.whl (32 kB)
# Downloading quadrilateral_fitter-1.12-py3-none-any.whl (13 kB)
# Downloading ultralytics-8.3.59-py3-none-any.whl (906 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.8/906.8 kB 22.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Installing collected packages: pyzbar, quadrilateral-fitter, ultralytics-thop, ultralytics, qrdet, qreader
# Successfully installed pyzbar-0.1.9 qrdet-2.5 qreader-3.14 quadrilateral-fitter-1.12 ultralytics-8.3.59 ultralytics-thop-2.0.13
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts
#   imagemagick-6-common libdjvulibre-text libdjvulibre21 libfftw3-double3
#   libgs9 libgs9-common libidn12 libijs-0.35 libjbig2dec0 libjxr-tools libjxr0
#   liblqr-1-0 libmagickcore-6.q16-6 libmagickcore-6.q16-6-extra
#   libmagickwand-6.q16-6 libv4l-0 libv4lconvert0 libwmflite-0.2-7 poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   ghostscript-x libfftw3-bin libfftw3-dev inkscape poppler-utils
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts
#   imagemagick-6-common libdjvulibre-text libdjvulibre21 libfftw3-double3
#   libgs9 libgs9-common libidn12 libijs-0.35 libjbig2dec0 libjxr-tools libjxr0
#   liblqr-1-0 libmagickcore-6.q16-6 libmagickcore-6.q16-6-extra
#   libmagickwand-6.q16-6 libv4l-0 libv4lconvert0 libwmflite-0.2-7 libzbar0
#   poppler-data
# 0 upgraded, 25 newly installed, 0 to remove and 49 not upgraded.
# Need to get 24.1 MB of archives.
# After this operation, 82.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu8 [770 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick-6-common all 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [64.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickcore-6.q16-6 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [1,795 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickwand-6.q16-6 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [328 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.10 [752 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.10 [5,031 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ghostscript amd64 9.55.0~dfsg1-0ubuntu5.10 [49.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.5 [3,120 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdjvulibre-text all 3.5.28-2build2 [50.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdjvulibre21 amd64 3.5.28-2build2 [624 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr0 amd64 1.2~git20170615.f752187-5 [174 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr-tools amd64 1.2~git20170615.f752187-5 [16.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwmflite-0.2-7 amd64 0.2.12-5ubuntu1 [68.9 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickcore-6.q16-6-extra amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [70.1 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4lconvert0 amd64 1.22.1-2build1 [82.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4l-0 amd64 1.22.1-2build1 [44.9 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzbar0 amd64 0.23.92-4build2 [121 kB]
# Fetched 24.1 MB in 1s (16.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 25.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 123632 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../01-libfftw3-double3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../02-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../03-imagemagick-6-common_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.5_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Selecting previously unselected package libmagickcore-6.q16-6:amd64.
# Preparing to unpack .../04-libmagickcore-6.q16-6_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.5_amd64.deb ...
# Unpacking libmagickcore-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Selecting previously unselected package libmagickwand-6.q16-6:amd64.
# Preparing to unpack .../05-libmagickwand-6.q16-6_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.5_amd64.deb ...
# Unpacking libmagickwand-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../06-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../07-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../08-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../09-libgs9-common_9.55.0~dfsg1-0ubuntu5.10_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.10) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../10-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../11-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../12-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../13-libgs9_9.55.0~dfsg1-0ubuntu5.10_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.10) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../14-ghostscript_9.55.0~dfsg1-0ubuntu5.10_amd64.deb ...
# Unpacking ghostscript (9.55.0~dfsg1-0ubuntu5.10) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../15-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.5_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.5) ...
# Selecting previously unselected package libdjvulibre-text.
# Preparing to unpack .../16-libdjvulibre-text_3.5.28-2build2_all.deb ...
# Unpacking libdjvulibre-text (3.5.28-2build2) ...
# Selecting previously unselected package libdjvulibre21:amd64.
# Preparing to unpack .../17-libdjvulibre21_3.5.28-2build2_amd64.deb ...
# Unpacking libdjvulibre21:amd64 (3.5.28-2build2) ...
# Selecting previously unselected package libjxr0:amd64.
# Preparing to unpack .../18-libjxr0_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libjxr-tools.
# Preparing to unpack .../19-libjxr-tools_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr-tools (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libwmflite-0.2-7:amd64.
# Preparing to unpack .../20-libwmflite-0.2-7_0.2.12-5ubuntu1_amd64.deb ...
# Unpacking libwmflite-0.2-7:amd64 (0.2.12-5ubuntu1) ...
# Selecting previously unselected package libmagickcore-6.q16-6-extra:amd64.
# Preparing to unpack .../21-libmagickcore-6.q16-6-extra_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.5_amd64.deb ...
# Unpacking libmagickcore-6.q16-6-extra:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../22-libv4lconvert0_1.22.1-2build1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.22.1-2build1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../23-libv4l-0_1.22.1-2build1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.22.1-2build1) ...
# Selecting previously unselected package libzbar0:amd64.
# Preparing to unpack .../24-libzbar0_0.23.92-4build2_amd64.deb ...
# Unpacking libzbar0:amd64 (0.23.92-4build2) ...
# Setting up imagemagick-6-common (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libwmflite-0.2-7:amd64 (0.2.12-5ubuntu1) ...
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.5) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up libv4lconvert0:amd64 (1.22.1-2build1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up libdjvulibre-text (3.5.28-2build2) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.10) ...
# Setting up libjxr-tools (1.2~git20170615.f752187-5) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.10) ...
# Setting up libdjvulibre21:amd64 (3.5.28-2build2) ...
# Setting up ghostscript (9.55.0~dfsg1-0ubuntu5.10) ...
# Setting up libv4l-0:amd64 (1.22.1-2build1) ...
# Setting up libmagickcore-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up libmagickwand-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up libmagickcore-6.q16-6-extra:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up libzbar0:amd64 (0.23.92-4build2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link

# %%
from qreader import QReader
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import pandas as pd

# %%
detector = QReader()
# Out:
# /usr/local/lib/python3.10/dist-packages/qrdet/qrdet.py:129: UserWarning: QRDetector has been updated to use the new YoloV8 model. Use legacy=True when calling detect for backwards compatibility with 1.x versions. Or update to new output (new output is a tuple of dicts, containing several new information (1.x output is accessible through 'bbox_xyxy' and 'confidence').Forget this message if you are reading it from QReader. [This is a first download warning and will be removed at 2.1]
#   warn("QRDetector has been updated to use the new YoloV8 model. Use legacy=True when calling detect "
# Downloading weights...: 100%|██████████| 24.0M/24.0M [00:00<00:00, 71.1MiB/s]
